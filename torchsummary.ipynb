# %%
import torch
from torchsummary import summary
from models import SiameseNet, WDCNN

# %%
siamesenet = SiameseNet().to('cuda')
summary(siamesenet, torch.zeros((32, 2, 2048)), torch.zeros((32, 2, 2048)))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─Sequential: 1-1                        [-1, 100]                 --
# |    └─SeparableConv1D: 2-1              [-1, 14, 257]             --
# |    |    └─Conv1d: 3-1                  [-1, 58, 257]             3,770
# |    |    └─Conv1d: 3-2                  [-1, 14, 257]             826
# |    └─ReLU: 2-2                         [-1, 14, 257]             --
# |    └─MaxPool1d: 2-3                    [-1, 14, 85]              --
# |    └─SeparableConv1D: 2-4              [-1, 32, 85]              --
# |    |    └─Conv1d: 3-3                  [-1, 14, 85]              56
# |    |    └─Conv1d: 3-4                  [-1, 32, 85]              480
# |    └─ReLU: 2-5                         [-1, 32, 85]              --
# |    └─MaxPool1d: 2-6                    [-1, 32, 28]              --
# |    └─SeparableConv1D: 2-7              [-1, 64, 29]              --
# ...

# %%
wdcnn = WDCNN().to('cuda')
summary(wdcnn, torch.zeros((32, 2, 2048)))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─Sequential: 1-1                        [-1, 10]                  --
# |    └─SeparableConv1D: 2-1              [-1, 14, 257]             --
# |    |    └─Conv1d: 3-1                  [-1, 58, 257]             3,770
# |    |    └─Conv1d: 3-2                  [-1, 14, 257]             826
# |    └─ReLU: 2-2                         [-1, 14, 257]             --
# |    └─MaxPool1d: 2-3                    [-1, 14, 85]              --
# |    └─SeparableConv1D: 2-4              [-1, 32, 85]              --
# |    |    └─Conv1d: 3-3                  [-1, 14, 85]              56
# |    |    └─Conv1d: 3-4                  [-1, 32, 85]              480
# |    └─ReLU: 2-5                         [-1, 32, 85]              --
# |    └─MaxPool1d: 2-6                    [-1, 32, 28]              --
# |    └─SeparableConv1D: 2-7              [-1, 64, 29]              --
# ...
